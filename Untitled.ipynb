# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re

def check(paper):
    driver = webdriver.Firefox()
    driver.get('http://apps.webofknowledge.com/')

    # search settings

    sid = filter(lambda x: x.find('SID') == 0, driver.current_url.split('&'))[0]

    driver.get('http://apps.webofknowledge.com/WOS_CitedReferenceSearch_input.do?locale=zh_CN&errorKey=&viewType=input&product=WOS&search_mode=CitedReferenceSearch&' + sid)

    driver.find_element_by_class_name('settings-item').find_element_by_xpath('h4').click()
    try:
        cbs = driver.find_elements_by_xpath('//input[@type="checkbox" and @name="editions"]')
        if not cbs[0].is_selected():
            cbs[0].click()
        for cb in cbs[1:]:
            if cb.is_selected():
                cb.click()
    except:
        pass


    # input paper title

    driver.find_element_by_id('s2id_select1').click()
    driver.find_element_by_id('select2-results-1').find_elements_by_tag_name('li')[-1].click()

    driver.find_element_by_id('value(input1)').click()
    driver.find_element_by_id('value(input1)').clear()

#     s = unicode('Distributed data management using mapreduce')
    s = unicode(paper)
    driver.find_element_by_id('value(input1)').send_keys(s)

    # begin search
    driver.find_elements_by_id('WOS_CitedReferenceSearch_input_form_sb')[-1].click()


    #--------------------------------------------------------------------------------------------------

    # show full titles

    empty = False
    while True:
        try:
            driver.find_element_by_id('show_exp_titles_link').click()
            break
        except:
            try:
                driver.find_element_by_id('noRecordsDiv')
                empty = True
                break
            except:
                pass
            time.sleep(1)

    if empty:
        print 'no result for "%s"' % paper
        driver.quit()
        return

    table = driver.find_element_by_id('records_chunks')
    tbody = table.find_elements_by_tag_name('tbody')[-1]
    tr = tbody.find_elements_by_tag_name('tr')[0]
    td = tr.find_elements_by_tag_name('td')

    td[1].find_elements_by_tag_name('span')[2].click()
    author = td[1].find_elements_by_tag_name('span')[1].text

#     title = td[2].find_element_by_xpath('span[2]/span').text
    full_title = td[2].find_element_by_xpath('span[2]').text
    year = td[3].text
    volume = td[4].text
    season = td[5].text
    page = td[6].text
    
    print author
#     print title
    print full_title
    print year
    print volume
    print season
    print page

    # driver.find_elements_by_name('Select All')[0].click()
    # time.sleep(3)
    for cb in driver.find_elements_by_xpath('//input[@name="isickref" and @type="checkbox"]'):
        cb.click()

    while True:
        try:
            driver.find_elements_by_name('Finish Search')[0].click()
            break
        except:
            time.sleep(1)

    while True:
        try:
            total_cites = int(driver.find_elements_by_class_name('title4')[0].find_element_by_xpath('span').text)
            break
        except:
            time.sleep(1)

    # # select all page
    # # driver.find_elements_by_class_name('page-options-inner-left')[0].find_element_by_xpath('ul/li/input').click()
    # driver.find_element_by_class_name('SelectPageChk').click()
    # driver.find_element_by_class_name('addToMarkedListButton').click()
    # try:
    #     driver.find_element_by_xpath('//input[@name="add"]').click()
    # except:
    #     pass
    # next = driver.find_element_by_class_name('paginationNext')
    # while next.get_attribute('class').find('paginationNextDisabled') < 0:
    #     next.click()
    # #     driver.find_elements_by_class_name('page-options-inner-left')[0].find_element_by_xpath('ul/li/input').click()
    #     driver.find_element_by_class_name('SelectPageChk').click()
    #     driver.find_element_by_class_name('addToMarkedListButton').click()
    #     try:
    #         driver.find_element_by_xpath('//input[@name="add"]').click()
    #     except:
    #         pass
    #     next = driver.find_element_by_class_name('paginationNext')


    index = 1
    while index <= total_cites:
        while True:
            try:
                record = driver.find_element_by_id('RECORD_' + str(index)).find_element_by_xpath('div[3]');
                break
            except:
                time.sleep(1)

        for i in range(10):
            try:
                record = driver.find_element_by_id('RECORD_' + str(index)).find_element_by_xpath('div[3]');
            except:
                break
            t = record.find_element_by_xpath('div[1]').text
            a = record.find_element_by_xpath('div[2]').text
            j = record.find_element_by_xpath('div[3]').text

            print index
            print t
            print a
            j = j.replace('\n', '')
            j = re.sub(r'\s+', ' ', j);
            print j

            index += 1

        if index < total_cites:
            driver.find_element_by_class_name('paginationNext').click()

    driver.quit()

# check('Adaptive logging: Optimizing logging and recovery costs in distributed in-memory databases')

with open('papers.txt') as f:
    for paper in f:
        if not paper.startswith('#'):
            check(paper[:-1])

#check('Targeted advertising in public transportation systems with quantitative evaluation')
# Out:
# Fan, K-W.; Sinha, P.
#
# 会议: Proc. of 5th IEEE MASS  会议地点: Atlanta, Georgia
# 标题: Distributed online data aggregation for large scale sensor networks
# 2008
#
#
# 153
# 1
# Data-locality-aware mapreduce real-time scheduling framework
# 作者: Kao, Yu-Chon; Chen, Ya-Shu
# JOURNAL OF SYSTEMS AND SOFTWARE 卷: 112 页: 65-77 出版年: FEB 2016
# 2
# In-Memory Big Data Management and Processing: A Survey
# 作者: Zhang, Hao; Chen, Gang; Ooi, Beng Chin; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 27 期: 7 页: 1920-1948 出版年: JUL 2015
# 3
# Progressive online aggregation in a distributed stream system
# 作者: Yang, Dingyu; Cao, Jian; Wu, Sai; 等.
# JOURNAL OF SYSTEMS AND SOFTWARE 卷: 102 页: 146-157 出版年: APR 2015
# 4
# OATS: online aggregation with two-level sharing strategy in cloud
# 作者: Wang, Yuxiang; Luo, Junzhou; Song, Aibo; 等.
# DISTRIBUTED AND PARALLEL DATABASES 卷: 32 期: 4 页: 467-505 出版年: DEC 2014
# 5
# Communication-efficient processing of multiple continuous aggregate queries
# 作者: Jeon, Joo Hyuk; Lee, Ki Yong; Kim, Myoung Ho
# INFORMATION SCIENCES 卷: 284 特刊: SI 页: 1-17 出版年: NOV 10 2014
# 6
# PF-OLA: a high-performance framework for parallel online aggregation
# 作者: Qin, Chengjie; Rusu, Florin
# DISTRIBUTED AND PARALLEL DATABASES 卷: 32 期: 3 特刊: SI 页: 337-375 出版年: SEP 2014
# 7
# BestPeer plus plus : A Peer-to-Peer Based Large-Scale Data Processing Platform
# 作者: Chen, Gang; Hu, Tianlei; Jiang, Dawei; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 26 期: 6 页: 1316-1331 出版年: JUN 2014
# 8
# Partition-Based Online Aggregation with Shared Sampling in the Cloud
# 作者: Wang, Yu-Xiang; Luo, Jun-Zhou; Song, Ai-Bo; 等.
# JOURNAL OF COMPUTER SCIENCE AND TECHNOLOGY 卷: 28 期: 6 页: 989-1011 出版年: NOV 2013
# 9
# OLAP query reformulation in peer-to-peer data warehousing
# 作者: Golfarelli, M.; Mandreoli, F.; Penzo, W.; 等.
# 会议: 13th ACM Data Warehousing and OLAP Workshop (DOLAP) 会议地点: Toronto, CANADA 会议日期: 2010
# 10
# Making data-centric storage adaptive and cost-optimal
# 作者: Joung, Yuh-Jzer; Huang, Shih-Hsiang; Lin, Shi-Hang
# COMPUTER NETWORKS 卷: 56 期: 1 页: 213-230 出版年: JAN 12 2012
# 11
# Survey of mobile object tracking protocols in Wireless Sensor Networks: a network-centric perspective
# 作者: Naderan, Marjan; Dehghan, Mehdi; Pedram, Hossein; 等.
# INTERNATIONAL JOURNAL OF AD HOC AND UBIQUITOUS COMPUTING 卷: 11 期: 1 页: 34-63 出版年: 2012
# 12
# Facilitating Efficient Object Tracking in Large-Scale Traceability Networks
# 作者: Wu, Yanbo; Sheng, Quan Z.; Ranasinghe, Damith C.
# COMPUTER JOURNAL 卷: 54 期: 12 页: 2053-2071 出版年: NOV 2011
# 13
# Approximate Aggregations in Structured P2P Networks
# 作者: Sun, Dalie; Wu, Sai; Jiang, Shouxu; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 23 期: 11 页: 1748-1752 出版年: NOV 2011
# Wu, Sai; Vu, Quang Hieu; Li, Hanzhong; Tan, Kian-Lee; IEEE
# ICDE: 2009 IEEE 25TH INTERNATIONAL CONFERENCE ON DATA ENGINEERING, VOLS 1-3
# 会议: IEEE 25th International Conference on Data Engineering  会议地点: Shanghai, PEOPLES R CHINA  会议日期: MAR 29-APR 02, 2009  会议赞助商: MICROSOFT; Shanghai Municipal Informat Commiss; hp invent; IBM; NSFC; Yahoo
# 标题: Adaptive Multi-Join Query Processing in PDBMS
# 2009
#
#
# 1239
# 1
# BestPeer plus plus : A Peer-to-Peer Based Large-Scale Data Processing Platform
# 作者: Chen, Gang; Hu, Tianlei; Jiang, Dawei; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 26 期: 6 页: 1316-1331 出版年: JUN 2014
# Sun, Dalie; Wu, Sai; Li, Jianzhong; Tung, Anthony K. H.
#
# 会议: Proceedings of the IEEE International Conference on Data Engineering (ICDE'08) Workshops
# 标题: Skyline-join in distributed databases
# 2008
#
#
#
# 1
# Online Subgraph Skyline Analysis over Knowledge Graphs
# 作者: Zheng, Weiguo; Lian, Xiang; Zou, Lei; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 28 期: 7 页: 1805-1819 出版年: JUL 1 2016
# 2
# Efficient Processing of Skyline-Join Queries over Multiple Data Sources
# 作者: Nagendra, Mithila; Candan, K. Selcuk
# ACM TRANSACTIONS ON DATABASE SYSTEMS 卷: 40 期: 2 文献号: 10 出版年: JUN 2015
# 3
# SEPT: an efficient skyline join algorithm on massive data
# 作者: Han, Xixian; Li, Jianzhong; Gao, Hong; 等.
# KNOWLEDGE AND INFORMATION SYSTEMS 卷: 43 期: 2 页: 355-388 出版年: MAY 2015
# 4
# Skyline and mapping aware join query evaluation
# 作者: Raghavan, Venkatesh; Rundensteiner, Elke A.; Srivastava, Shweta
# INFORMATION SYSTEMS 卷: 36 期: 6 页: 917-936 出版年: SEP 2011
# Wu, S.; Li, J.; Ooi, B.; Tan, K.-L
#
# 会议: ACM SIGMOD International Conference on Management of Data
# 标题: Just-in-time query retrieval over partially indexed data on structured p2p overlays
# 2008
#
#
# 279
# 1
# BestPeer plus plus : A Peer-to-Peer Based Large-Scale Data Processing Platform
# 作者: Chen, Gang; Hu, Tianlei; Jiang, Dawei; 等.
# IEEE TRANSACTIONS ON KNOWLEDGE AND DATA ENGINEERING 卷: 26 期: 6 页: 1316-1331 出版年: JUN 2014
# 2
# An efficient search mechanism for supporting partial filename queries in structured peer-to-peer overlay
# 作者: Lee, Guanling; Peng, Sheng-Lung; Chen, Yi-Chun; 等.
# PEER-TO-PEER NETWORKING AND APPLICATIONS 卷: 5 期: 4 特刊: SI 页: 340-349 出版年: DEC 2012
# 3
# Cross-layer routing for peer database querying over mobile ad hoc networks
# 作者: Papapetrou, Evangelos; Vassiliadis, Panos; Rova, Efthymia; 等.
# COMPUTER NETWORKS 卷: 56 期: 2 页: 504-520 出版年: FEB 2 2012
# 4
# Facilitating Efficient Object Tracking in Large-Scale Traceability Networks
# 作者: Wu, Yanbo; Sheng, Quan Z.; Ranasinghe, Damith C.
# COMPUTER JOURNAL 卷: 54 期: 12 页: 2053-2071 出版年: NOV 2011
# 5
# Sense The Physical, Walkthrough The Virtual, Manage The Co (existing) Spaces: A Database Perspective
# 作者: Ooi, Beng Chin; Tan, Kian Lee; Tung, Anthony
# SIGMOD RECORD 卷: 38 期: 3 页: 5-10 出版年: SEP 2009
